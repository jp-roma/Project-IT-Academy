# %% [markdown]
# ### EDA absentismo laboral (dataset RRHH)

# %%
"""
Carga de datos
"""
# Importa todas las bibliotecas necesarias para este NoteBook
import pandas  as pd
import numpy   as np
import seaborn as sns
import matplotlib.pyplot as plt
from EDA_helpers import (
    load_tables,
    categorizar_ausentismo,
    categorizar_ausencias,
    categorizar_distancias
)

tablas_db = ['ausentismo', 'long_absence']

# Paleta de colores Seaborn Set2, para usarla con MatPlotLib y seguir el mismo estilo
sns_color_set2 = ["#66c2a5", "#fc8d62", "#8da0cb", "#e78ac3", "#a6d854", "#ffd92f", "#e5c494", "#b3b3b3"]
colores = sns_color_set2

df = load_tables(tablas_db)

# Extrae los dataframes del diccionario que devuelve `load_tables()`
for t in df:
    globals()[f'df_{t}'] = df[t]
# Out:
# Cargando los datos de la tabla ausentismo
# Cargando los datos de la tabla long_absence

# %%
# Categorizar las columnas Month_absence, Day_of_week y Season.
df_ausentismo = categorizar_ausentismo(df_ausentismo)
# Clasificar las ausencias en dos categorías (Justificada / Injustificada)
df_ausentismo = categorizar_ausencias(df_ausentismo)
# Clasificar las distancias al trabajo, en franjas de kms.
df_ausentismo = categorizar_distancias(df_ausentismo)

del globals()['df_long_absence']
df_niveles = df['long_absence']

df_ausentismo.head()
# Out:
#    id  reason_id                                     absence_reason  \
# 0  14         11                   Diseases of the digestive system
# 1  36         13  Diseases of the musculoskeletal system and con...
# 2   9          6                     Diseases of the nervous system
# 3  28          9                 Diseases of the circulatory system
# 4   9         12       Diseases of the skin and subcutaneous tissue
#
#    justified  Absenteeism_hours  Month_absence_num Month_absence  Day_week  \
# 0          1                120                 11      November         2
# 1          1                120                  4         April         4
# 2          1                120                  7          July         3
# 3          1                112                  7          July         3
# 4          1                112                  3         March         3
#
#   Day_of_week  Season  ...  Social_drinker  Social_smoker  children  pets  \
# 0      Monday  Spring  ...               1              0         2     0
# 1   Wednesday  Winter  ...               1              0         1     0
# 2     Tuesday  Summer  ...               0              0         2     1
# 3     Tuesday  Summer  ...               0              0         1     2
# 4     Tuesday  Autumn  ...               0              0         2     1
#
#    weight  height  bmi  Group  Absence_type  distance_categories
# 0      95     196   25  26-35     Justified     entre 10 y 20 km
# 1      98     178   31  46-54     Justified     entre 10 y 20 km
# 2      65     172   22  55-65     Justified     entre 10 y 20 km
# 3      69     169   24  26-35     Justified     entre 21 y 30 km
# 4      65     172   22  55-65     Justified     entre 10 y 20 km
#
# [5 rows x 28 columns]

# %%
# Exportamos el DF a un archivo .csv para luego utilizarlo en el análisis de KPI's.
df_ausentismo.to_csv('RRHH_20251201.csv')

# %% [markdown]
# #### Descripción estadística

# %%
#Resumen estadístico inicial
df_ausentismo.describe().transpose()
# Out:
#                     count        mean         std      min      25%      50%  \
# id                 1106.0   78.991863  106.513742    1.000   14.000   28.000
# reason_id          1106.0   19.163653    8.324058    0.000   13.000   23.000
# justified          1106.0    0.904159    0.294506    0.000    1.000    1.000
# Absenteeism_hours  1106.0    8.625678   18.039349    0.000    2.000    3.000
# Month_absence_num  1106.0    6.356239    3.443617    1.000    3.000    6.000
# Day_week           1106.0    3.912297    1.416928    2.000    3.000    4.000
# tr_expense         1106.0  221.972875   67.153887  118.000  179.000  225.000
# dist2work          1106.0   29.395118   14.805842    5.000   16.000   26.000
# Service_time       1106.0   12.493671    4.391112    1.000    9.000   12.000
# work_load_avg      1106.0  272.049706   39.163773  205.917  244.387  264.604
# Hit_target         1106.0   94.609403    3.852867   81.000   93.000   95.000
# disciplined        1106.0    0.050633    0.219346    0.000    0.000    0.000
# Age                1106.0   36.456600    6.662410   27.000   31.000   37.000
# Education          1106.0    1.286618    0.668721    1.000    1.000    1.000
# Social_drinker     1106.0    0.556058    0.497072    0.000    0.000    1.000
# Social_smoker      1106.0    0.066908    0.249975    0.000    0.000    0.000
# children           1106.0    1.013562    1.086651    0.000    0.000    1.000
# pets               1106.0    0.751356    1.274399    0.000    0.000    0.000
# weight             1106.0   78.977396   12.777541   56.000   69.000   80.000
# height             1106.0  172.126582    6.010871  163.000  169.000  171.000
# bmi                1106.0   26.667269    4.256010   19.000   24.000   25.000
#
#                        75%      max
# id                 108.750  386.000
# reason_id           26.000   28.000
# justified            1.000    1.000
# Absenteeism_hours    8.000  120.000
# Month_absence_num   10.000   12.000
# Day_week             5.000    6.000
# tr_expense         260.000  388.000
# dist2work           50.000   52.000
# Service_time        16.000   29.000
# work_load_avg      294.217  378.884
# Hit_target          98.000  100.000
# disciplined          0.000    1.000
# Age                 40.000   58.000
# Education            1.000    4.000
# Social_drinker       1.000    1.000
# Social_smoker        0.000    1.000
# children             2.000    4.000
# pets                 1.000    8.000
# weight              89.000  108.000
# height             172.000  196.000
# bmi                 31.000   38.000

# %%
# Distribución de datos categóricos
import numpy as np
df_ausentismo_cat = df_ausentismo.select_dtypes(exclude=np.number)
df_ausentismo_cat.describe().transpose()
# Out:
#                     count unique                   top  freq
# absence_reason       1106     28  medical consultation   213
# Month_absence        1106     12                 March   127
# Day_of_week          1106      5               Tuesday   238
# Season               1106      4                Spring   294
# Group                1106      4                 36-45   533
# Absence_type         1106      2             Justified  1000
# distance_categories  1106      6      entre 10 y 20 km   338

# %%
#Agrupar por 'absence_reason' para determinar los motivos más frecuentes de absentismo laboral.
df_ausencias_razon = df_ausentismo \
                        .groupby('absence_reason')['reason_id'] \
                        .count() \
                        .sort_values(ascending=False)
df_ausencias_razon
# Out:
# absence_reason
# medical consultation                                                                                   213
# dental consultation                                                                                    173
# physiotherapy                                                                                           96
# Diseases of the musculoskeletal system and connective tissue                                            88
# Injury, poisoning and certain other consequences of external causes                                     65
# Unknown                                                                                                 56
# Patient fol-up                                                                                          56
# unjustified absence                                                                                     50
# laboratory examination                                                                                  44
# Diseases of the digestive system                                                                        42
# Diseases of the respiratory system                                                                      38
# Diseases of the genitourinary system                                                                    32
# Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified                 32
# Certain infectious and parasitic diseases                                                               24
# Diseases of the eye and adnexa                                                                          20
# Diseases of the skin and subcutaneous tissue                                                            14
# Diseases of the nervous system                                                                          13
# Diseases of the circulatory system                                                                      11
# Diseases of the ear and mastoid process                                                                 10
# Factors influencing health status and contact with health services.                                      6
# Mental and behavioural disorders                                                                         5
# Certain conditions originating in the perinatal period                                                   5
# blood, donation                                                                                          4
# Endocrine, nutritional and metabolic diseases                                                            3
# Pregnancy, childbirth and the puerperium                                                                 2
# Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism      2
# Neoplasms                                                                                                1
# Congenital malformations, deformations and chromosomal abnormalities                                     1
# Name: reason_id, dtype: int64

# %%
# Cantidad de total de horas de ausencias por ID empleado
cantidad_ausencias = (
	df_ausentismo
		.groupby('id')['Absenteeism_hours']
		.sum() \
        .sort_values(ascending=False)
)
cantidad_ausencias.head()
# Out:
# id
# 14    844
# 9     726
# 36    631
# 28    571
# 11    554
# Name: Absenteeism_hours, dtype: int64

# %%
# Calcular el total de absentismo por Mes

total_por_mes = df_ausentismo.groupby('Month_absence', observed=False)['id'].count()
total_por_mes
# Out:
# Month_absence
# January       83
# February     103
# March        127
# April         79
# May          100
# June          70
# July         110
# August        79
# September     76
# October      109
# November      92
# December      78
# Name: id, dtype: int64

# %%
#Calcular la media de absentismo por mes

# 1. Calcular la media de Absenteeism_hours por Month_absence
media_por_mes = df_ausentismo.groupby('Month_absence', observed=False)['Absenteeism_hours'].mean().reset_index()

# 2. Eliminar meses que no están presentes en los datos (si aplica) y ordenar
media_h_por_mes = media_por_mes.dropna(subset=['Month_absence'])

# 3. Formatear la media a dos decimales
media_h_por_mes['Absenteeism_hours'] = media_h_por_mes['Absenteeism_hours'].round(2)
media_h_por_mes
# Out:
#    Month_absence  Absenteeism_hours
# 0        January               3.92
# 1       February               4.17
# 2          March              13.38
# 3          April              12.75
# 4            May               7.11
# 5           June               9.36
# 6           July              14.48
# 7         August               5.51
# 8      September               6.41
# 9        October               5.22
# 10      November               9.39
# 11      December               9.82

# %%
# Calcular el total de horas de ausentismo por Mes

# 1. Calcular el TOTAL de Absenteeism_hours por Month_absence
# Agrupamos por el mes y calculamos la SUMA de las horas de absentismo.
total_por_mes = df_ausentismo.groupby('Month_absence', observed=False)['Absenteeism_hours'].sum().reset_index()


# Eliminar meses que no están presentes en los datos y ordenar el DataFrame
total_h_por_mes = total_por_mes.dropna(subset=['Month_absence'])
total_h_por_mes
# Out:
#    Month_absence  Absenteeism_hours
# 0        January                325
# 1       February                429
# 2          March               1699
# 3          April               1007
# 4            May                711
# 5           June                655
# 6           July               1593
# 7         August                435
# 8      September                487
# 9        October                569
# 10      November                864
# 11      December                766

# %%
# Calcular el total de ausencias No justificadas y Justificadas para el período analizado.
Tipo_ausencia = df_ausentismo.groupby('Absence_type')['id'].count().sort_values(ascending=False)
Tipo_ausencia
# Out:
# Absence_type
# Justified      1000
# Unjustified     106
# Name: id, dtype: int64

# %%
# Calcular el total de empleados por tramos de distancia al trabajo.

distancia = df_ausentismo[['id','distance_categories']].drop_duplicates()
distancia.groupby('distance_categories')['id'].count().sort_values(ascending=False)
# Out:
# distance_categories
# entre 21 y 30 km    121
# entre 10 y 20 km    116
# mas de 50 km         70
# entre 31 y 40 km     41
# entre 41 y 50 km     34
# menos de 10 km        2
# Name: id, dtype: int64

# %% [markdown]
# ### Visualizaciones EDA (df_ausentismo)
# #### Visualización: Plots por variables Categóricas

# %%
# Configuración básica para los gráficos
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 100 # Mejora de la resolución de los gráficos

# Distribución de datos categóricos
df_ausentismo_cat = df_ausentismo.select_dtypes(exclude=np.number)
df_ausentismo_cat.head()
# Out:
#                                       absence_reason Month_absence  \
# 0                   Diseases of the digestive system      November
# 1  Diseases of the musculoskeletal system and con...         April
# 2                     Diseases of the nervous system          July
# 3                 Diseases of the circulatory system          July
# 4       Diseases of the skin and subcutaneous tissue         March
#
#   Day_of_week  Season  Group Absence_type distance_categories
# 0      Monday  Spring  26-35    Justified    entre 10 y 20 km
# 1   Wednesday  Winter  46-54    Justified    entre 10 y 20 km
# 2     Tuesday  Summer  55-65    Justified    entre 10 y 20 km
# 3     Tuesday  Summer  26-35    Justified    entre 21 y 30 km
# 4     Tuesday  Autumn  55-65    Justified    entre 10 y 20 km

# %% [markdown]
# #### Visualizaciones por variables categóricas y numéricas

# %% [markdown]
# #### Visualización: Correlación entre variables laborales y personales

# %%
# Utilizamos el DF importado con los datos categorizados.
df_niveles.head()
# Out:
#    ID  work_days_absent  ab_level       level
# 0  14            105.50         1  Medio-Alto
# 1  36             78.88         1  Medio-Alto
# 2   9             90.75         1  Medio-Alto
# 3  28             71.38         1  Medio-Alto
# 4  11             69.25         1  Medio-Alto

# %%
# Realizamos la unión de los DF ausentismo y niveles, mediante el método .merge()

df_integrado = df_ausentismo.merge(df_niveles, left_on='id', right_on='ID', how='inner')
df_integrado.head()
# Out:
#    id  reason_id                                     absence_reason  \
# 0  14         11                   Diseases of the digestive system
# 1  36         13  Diseases of the musculoskeletal system and con...
# 2   9          6                     Diseases of the nervous system
# 3  28          9                 Diseases of the circulatory system
# 4   9         12       Diseases of the skin and subcutaneous tissue
#
#    justified  Absenteeism_hours  Month_absence_num Month_absence  Day_week  \
# 0          1                120                 11      November         2
# 1          1                120                  4         April         4
# 2          1                120                  7          July         3
# 3          1                112                  7          July         3
# 4          1                112                  3         March         3
#
#   Day_of_week  Season  ...  weight  height  bmi  Group  Absence_type  \
# 0      Monday  Spring  ...      95     196   25  26-35     Justified
# 1   Wednesday  Winter  ...      98     178   31  46-54     Justified
# 2     Tuesday  Summer  ...      65     172   22  55-65     Justified
# 3     Tuesday  Summer  ...      69     169   24  26-35     Justified
# 4     Tuesday  Autumn  ...      65     172   22  55-65     Justified
#
#    distance_categories  ID  work_days_absent  ab_level       level
# 0     entre 10 y 20 km  14            105.50         1  Medio-Alto
# 1     entre 10 y 20 km  36             78.88         1  Medio-Alto
# 2     entre 10 y 20 km   9             90.75         1  Medio-Alto
# 3     entre 21 y 30 km  28             71.38         1  Medio-Alto
# 4     entre 10 y 20 km   9             90.75         1  Medio-Alto
#
# [5 rows x 32 columns]

# %%
# Tabla frecuencia de ausencias por nivel de absentismo

frecuencia_absoluta = df_niveles['level'].value_counts()
frecuencia_relativa = frecuencia_absoluta / len(df_niveles['level'])
frecuencia_relativa_porcentual = (frecuencia_relativa * 100).round(2)
frecuencia_relativa_acumulada = frecuencia_relativa.cumsum()

Tabla_frecuencias = pd.DataFrame({'Frecuencia absoluta':frecuencia_absoluta,'Frecuencia relativa': frecuencia_relativa,
                                'Frecuencia relativa %': frecuencia_relativa_porcentual,
                    'Frecuencia relativa acumulada': frecuencia_relativa_acumulada})
Tabla_frecuencias
# Out:
#             Frecuencia absoluta  Frecuencia relativa  Frecuencia relativa %  \
# level
# Bajo                        370             0.966057                  96.61
# Medio-Alto                   13             0.033943                   3.39
#
#             Frecuencia relativa acumulada
# level
# Bajo                             0.966057
# Medio-Alto                       1.000000

# %%
# Tabla cruzada para analizar los perfiles de riesgo de empleados y niveles de absentismo (Días por niveles)

cantidad_dias = df_niveles.groupby('level')['work_days_absent'].sum().sort_values(ascending=False)
cantidad_dias
# Out:
# level
# Medio-Alto    738.40
# Bajo          454.62
# Name: work_days_absent, dtype: float64

# %%
# Gráfico de barras para cuantificar la cantidad de dias de absentismo por niveles ordinales
# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=cantidad_dias.index,
    y=cantidad_dias.values,
    palette='Set2',
    hue=cantidad_dias,
    legend=False
)

# Añadir etiquetas y título
plt.title('Cantidad de dias de ausencia por Nivel de absentismo', fontsize=16)
plt.xlabel('Niveles', fontsize=14)
plt.ylabel('Cantidad de dias', fontsize=14)

# Rotar las etiquetas del eje X para que sean legibles
plt.xticks(rotation=45, ha='right')

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %%
# Gráfico de barras para cuantificar la cantidad de empleados por niveles ordinales de absentismo
data = df_integrado.groupby('level')['id'].count().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=data.index,
    y=data.values,
    palette='Set2',
    hue=data,
    legend=False
)

# Añadir etiquetas y título
plt.title('Cantidad de empleados por Nivel de absentismo', fontsize=16)
plt.xlabel('Niveles', fontsize=14)
plt.ylabel('Cantidad de empleados', fontsize=14)

# Rotar las etiquetas del eje X para que sean legibles
plt.xticks(rotation=45, ha='right')

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %%
# Gráfico de barras para cuantificar la cantidad de empleados por variables personales y laborales
data = df_integrado.groupby('disciplined')['id'].count().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=data.index,
    y=data.values,
    palette='Set2',
    hue=data,
    legend=False
)

# Añadir etiquetas y título
plt.title('Cantidad de empleados por variable Disciplined', fontsize=16)
plt.xlabel('Disciplinados', fontsize=14)
plt.ylabel('Cantidad de empleados', fontsize=14)

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %%
# Gráfico de barras para cuantificar la cantidad de empleados por variables personales y laborales
data = df_integrado.groupby('Social_smoker')['id'].count().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=data.index,
    y=data.values,
    palette='Set2',
    hue=data,
    legend=False
)

# Añadir etiquetas y título
plt.title('Cantidad de empleados por variable Social_smoker', fontsize=16)
plt.xlabel('Fumadores', fontsize=14)
plt.ylabel('Cantidad de empleados', fontsize=14)

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %%
# Gráfico de barras para cuantificar la cantidad de empleados por variables personales y laborales
data = df_integrado.groupby('Social_drinker')['id'].count().sort_values(ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(
    x=data.index,
    y=data.values,
    palette='Set2',
    hue=data,
    legend=False
)

# Añadir etiquetas y título
plt.title('Cantidad de empleados por variable Social_drinker', fontsize=16)
plt.xlabel('Bebedores', fontsize=14)
plt.ylabel('Cantidad de empleados', fontsize=14)

plt.tight_layout() # Ajustar el diseño para que todo quepa
plt.show()

# %%
# Correlación de variables laborales con niveles de absentismo (work_days_absent)

# Calculamos la correlación entre las variables laborales y los niveles de absentismo.
correlation = df_integrado[['disciplined', 'Hit_target', 'work_load_avg', 'Service_time', 'work_days_absent']].corr()

# Creamos el mapa de calor
plt.figure(figsize=(8,4))
mapa = sns.heatmap(
    correlation, 
    cmap='coolwarm_r',
    annot=True, 
    fmt='.2f', 
    vmin=-1, 
    vmax=1, 
    center=0, 
    linewidths=0.8
)
mapa.figure.subplots_adjust(top=0.9)
mapa.figure.suptitle('Correlación entre Variables laborales y dias de absentismo', fontsize=10)
plt.show()

# %%
# Correlación de variables personales con dias de absentismo (work_days_absent)

# Calculamos la correlación entre las variables personales y los niveles de absentismo.
correlation2 = df_integrado[['Age', 'Education', 'weight', 'height', 'children', 'bmi','dist2work','Social_smoker', 'Social_drinker','work_days_absent']].corr()

# Creamos el mapa de calor
plt.figure(figsize=(8,4))
mapa = sns.heatmap(correlation2, 
                   cmap='coolwarm_r',
                   annot=True, 
                   fmt='.2f', 
                   vmin=-1, 
                   vmax=1, 
                   center=0, 
                   linewidths=0.8)
mapa.figure.subplots_adjust(top=0.9)
mapa.figure.suptitle('Correlación entre Variables personales y días de absentismo', fontsize=10)
plt.show()

# %%
# Descartar multicolinealidad entre variables independientes (correlación)
# Calculamos la correlación entre las variables independientes (smoker, drinker, disciplined).

correlation3 = df_integrado[['Social_smoker', 'Social_drinker', 'disciplined']].corr()
correlation3
# Out:
#                 Social_smoker  Social_drinker  disciplined
# Social_smoker        1.000000       -0.117611     0.086703
# Social_drinker      -0.117611        1.000000     0.048645
# disciplined          0.086703        0.048645     1.000000
